# %% [markdown]
# ### Part 3 - Tuples

# %% [markdown]
# 0. Create a tuple

# %%
tuple_ages=(20, 25, 22, 30, 28)

# %% [markdown]
# 1. Print the tuple

# %%
print(tuple_ages)
# Out:
# (20, 25, 22, 30, 28)

# %% [markdown]
# 2. Display the first and last elements

# %%
# The first element
print("The first element is",tuple_ages[0])


# The last element
print("The last element is",tuple_ages[-1])
# Out:
# The first element is 20
# The last element is 28

# %% [markdown]
# 3. Display:
# - the maximum value
# - the minimum value
# - the number of elements

# %%
# The maximum value
print("The maximum value is",max(tuple_ages))

# The minimum value
print("The minimun value is",min(tuple_ages))

# The number of elements
print("The number of elements is",len(tuple_ages))
# Out:
# The maximum value is 30
# The minimun value is 20
# The number of elements is 5

# %% [markdown]
# 4. Try to modify one of the elements of the tuple

# %%
#tuple_ages[3] = 27
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 tuple_ages[3] = 27
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5. Write a brief comment in the script explaining why Python does not allow this modification

# %% [markdown]
# Python doesn't allow this modification because the elements of a tuple cannot be changed. This can be useful in some cases when it is necessary to ensure that the data doesn't change.
